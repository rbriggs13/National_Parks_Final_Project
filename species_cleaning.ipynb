# %%
#import dependencies
import pandas as pd

# %%
species_df = pd.read_csv('Resources/species.csv')
species_df.head()
# Out:
# C:\Users\ryanb\anaconda3\envs\PythonData\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (13) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   Species ID             Park Name Category         Order    Family  \
# 0  ACAD-1000  Acadia National Park   Mammal  Artiodactyla  Cervidae
# 1  ACAD-1001  Acadia National Park   Mammal  Artiodactyla  Cervidae
# 2  ACAD-1002  Acadia National Park   Mammal     Carnivora   Canidae
# 3  ACAD-1003  Acadia National Park   Mammal     Carnivora   Canidae
# 4  ACAD-1004  Acadia National Park   Mammal     Carnivora   Canidae
#
#           Scientific Name                                       Common Names  \
# 0             Alces alces                                              Moose
# 1  Odocoileus virginianus  Northern White-Tailed Deer, Virginia Deer, Whi...
# 2           Canis latrans                             Coyote, Eastern Coyote
# 3             Canis lupus        Eastern Timber Wolf, Gray Wolf, Timber Wolf
# 4           Vulpes vulpes  Black Fox, Cross Fox, Eastern Red Fox, Fox, Re...
#
#   Record Status     Occurrence  Nativeness Abundance Seasonality  \
# 0      Approved        Present      Native      Rare    Resident
# 1      Approved        Present      Native  Abundant         NaN
# 2      Approved        Present  Not Native    Common         NaN
# 3      Approved  Not Confirmed      Native       NaN         NaN
# 4      Approved        Present     Unknown    Common     Breeder
#
#   Conservation Status Unnamed: 13
# 0                 NaN         NaN
# 1                 NaN         NaN
# 2  Species of Concern         NaN
# 3          Endangered         NaN
# 4                 NaN         NaN

# %%
#exploring the data
species_df.groupby(['Park Name'])['Scientific Name'].count()
# Out:
# Park Name
# Acadia National Park                              1709
# Arches National Park                              1048
# Badlands National Park                            1389
# Big Bend National Park                            2269
# Biscayne National Park                            1726
# Black Canyon of the Gunnison National Park        1106
# Bryce Canyon National Park                        1286
# Canyonlands National Park                         1223
# Capitol Reef National Park                        1566
# Carlsbad Caverns National Park                    1536
# Channel Islands National Park                     1885
# Congaree National Park                            2321
# Crater Lake National Park                         3760
# Cuyahoga Valley National Park                     1941
# Death Valley National Park                        4439
# Denali National Park and Preserve                 1320
# Dry Tortugas National Park                         848
# Everglades National Park                          2084
# Gates Of The Arctic National Park and Preserve    1353
# Glacier Bay National Park and Preserve            1957
# Glacier National Park                             2556
# Grand Canyon National Park                        2622
# Grand Teton National Park                         2030
# Great Basin National Park                         2653
# Great Sand Dunes National Park and Preserve        952
# Great Smoky Mountains National Park               6623
# Guadalupe Mountains National Park                 1746
# Haleakala National Park                           2580
# Hawaii Volcanoes National Park                    3298
# Hot Springs National Park                         1950
# Isle Royale National Park                         1397
# Joshua Tree National Park                         2294
# Katmai National Park and Preserve                 1225
# Kenai Fjords National Park                        1057
# Kobuk Valley National Park                        1025
# Lake Clark National Park and Preserve             2007
# Lassen Volcanic National Park                     1797
# Mammoth Cave National Park                        2499
# Mesa Verde National Park                          1243
# Mount Rainier National Park                       1743
# North Cascades National Park                      3363
# Olympic National Park                             1948
# Petrified Forest National Park                     853
# Pinnacles National Park                           1416
# Redwood National Park                             6310
# Rocky Mountain National Park                      3152
# Saguaro National Park                             1834
# Sequoia and Kings Canyon National Parks           1995
# Shenandoah National Park                          4655
# Theodore Roosevelt National Park                  1165
# Voyageurs National Park                           1453
# Wind Cave National Park                           1395
# Wrangell - St Elias National Park and Preserve    1796
# Yellowstone National Park                         3966
# Yosemite National Park                            2088
# Zion National Park                                1796
# Name: Scientific Name, dtype: int64

# %%
species_df.groupby(['Scientific Name'])['Park Name'].count().sort_values(ascending=False)
# Out:
# Scientific Name
# Falco peregrinus        56
# Circus cyaneus          55
# Tachycineta bicolor     54
# Accipiter striatus      54
# Pandion haliaetus       54
#                         ..
# Gymnodinium              1
# Gymnoderma lineare       1
# Gymnocolea acutiloba     1
# Gymnocladus dioica       1
# physa virgata            1
# Name: Park Name, Length: 46022, dtype: int64

# %%
species_df['Occurrence'].value_counts()
# Out:
# Present                            83278
# Not Confirmed                      11958
# Not Present (False Report)          2072
# Not Present (Historical Report)     1310
# Not Present                          431
# Approved                              51
# In Review                              6
# Name: Occurrence, dtype: int64

# %%
species_df['Nativeness'].value_counts()
# Out:
# Native           75950
# Not Native       11095
# Unknown           7101
# Present             53
# Not Confirmed        4
# Name: Nativeness, dtype: int64

# %%
#cleaning the data frame
clean_species_df = species_df[(species_df['Occurrence'].isin(['Present', 'Not Confirmed'])) & (species_df['Nativeness'] != 'Unknown')]

# %%
clean_species_df['Occurrence'].value_counts()
# Out:
# Present          77506
# Not Confirmed    11353
# Name: Occurrence, dtype: int64

# %%
clean_species_df['Nativeness'].value_counts()
# Out:
# Native        73903
# Not Native    10073
# Name: Nativeness, dtype: int64

# %%
clean_species_df.head()
# Out:
#   Species ID             Park Name Category         Order    Family  \
# 0  ACAD-1000  Acadia National Park   Mammal  Artiodactyla  Cervidae
# 1  ACAD-1001  Acadia National Park   Mammal  Artiodactyla  Cervidae
# 2  ACAD-1002  Acadia National Park   Mammal     Carnivora   Canidae
# 3  ACAD-1003  Acadia National Park   Mammal     Carnivora   Canidae
# 5  ACAD-1005  Acadia National Park   Mammal     Carnivora   Felidae
#
#           Scientific Name                                       Common Names  \
# 0             Alces alces                                              Moose
# 1  Odocoileus virginianus  Northern White-Tailed Deer, Virginia Deer, Whi...
# 2           Canis latrans                             Coyote, Eastern Coyote
# 3             Canis lupus        Eastern Timber Wolf, Gray Wolf, Timber Wolf
# 5         Lynx canadensis                                        Canada Lynx
#
#   Record Status     Occurrence  Nativeness Abundance Seasonality  \
# 0      Approved        Present      Native      Rare    Resident
# 1      Approved        Present      Native  Abundant         NaN
# 2      Approved        Present  Not Native    Common         NaN
# 3      Approved  Not Confirmed      Native       NaN         NaN
# 5      Approved  Not Confirmed      Native       NaN         NaN
#
#   Conservation Status Unnamed: 13
# 0                 NaN         NaN
# 1                 NaN         NaN
# 2  Species of Concern         NaN
# 3          Endangered         NaN
# 5                 NaN         NaN

# %%
clean_species_df = clean_species_df.drop(columns = ['Record Status', 'Abundance', 'Seasonality', 'Unnamed: 13'])
clean_species_df.head(10)
# Out:
#    Species ID             Park Name Category         Order      Family  \
# 0   ACAD-1000  Acadia National Park   Mammal  Artiodactyla    Cervidae
# 1   ACAD-1001  Acadia National Park   Mammal  Artiodactyla    Cervidae
# 2   ACAD-1002  Acadia National Park   Mammal     Carnivora     Canidae
# 3   ACAD-1003  Acadia National Park   Mammal     Carnivora     Canidae
# 5   ACAD-1005  Acadia National Park   Mammal     Carnivora     Felidae
# 8   ACAD-1008  Acadia National Park   Mammal     Carnivora  Mustelidae
# 9   ACAD-1009  Acadia National Park   Mammal     Carnivora  Mustelidae
# 11  ACAD-1011  Acadia National Park   Mammal     Carnivora  Mustelidae
# 12  ACAD-1012  Acadia National Park   Mammal     Carnivora  Mustelidae
# 13  ACAD-1013  Acadia National Park   Mammal     Carnivora  Mustelidae
#
#            Scientific Name                                       Common Names  \
# 0              Alces alces                                              Moose
# 1   Odocoileus virginianus  Northern White-Tailed Deer, Virginia Deer, Whi...
# 2            Canis latrans                             Coyote, Eastern Coyote
# 3              Canis lupus        Eastern Timber Wolf, Gray Wolf, Timber Wolf
# 5          Lynx canadensis                                        Canada Lynx
# 8         Lutra canadensis                                 Otter, River Otter
# 9          Martes pennanti                            Blackcat, Fisher, Pekan
# 11         Mustela erminea  Bonaparte Weasel, Bonaparte's Weasel, Ermine, ...
# 12         Mustela frenata  Long-Tailed Weasel, New York Weasel, Northern ...
# 13        Mustela macrodon           Ancient Sea Mink, Big Sea Mink, Sea Mink
#
#        Occurrence  Nativeness Conservation Status
# 0         Present      Native                 NaN
# 1         Present      Native                 NaN
# 2         Present  Not Native  Species of Concern
# 3   Not Confirmed      Native          Endangered
# 5   Not Confirmed      Native                 NaN
# 8         Present      Native                 NaN
# 9         Present      Native                 NaN
# 11        Present      Native                 NaN
# 12        Present      Native                 NaN
# 13  Not Confirmed      Native                 NaN

# %%
clean_species_df['Conservation Status'].value_counts()
# Out:
# Species of Concern     3459
# Endangered              244
# Under Review            143
# Threatened              136
# In Recovery              69
# Proposed Endangered      17
# Proposed Threatened       6
# Name: Conservation Status, dtype: int64

# %%
clean_species_df['Conservation Status'].isnull().sum()
# Out:
# 84785

# %%
clean_species_df['Conservation Status'] = clean_species_df['Conservation Status'].fillna(value = 'Least Concern')
clean_species_df['Conservation Status'].value_counts()
# Out:
# Least Concern          84785
# Species of Concern      3459
# Endangered               244
# Under Review             143
# Threatened               136
# In Recovery               69
# Proposed Endangered       17
# Proposed Threatened        6
# Name: Conservation Status, dtype: int64

# %%
clean_species_df = clean_species_df[(clean_species_df['Conservation Status'] != 'Under Review')]
clean_species_df['Conservation Status'].value_counts()
# Out:
# Least Concern          84785
# Species of Concern      3459
# Endangered               244
# Threatened               136
# In Recovery               69
# Proposed Endangered       17
# Proposed Threatened        6
# Name: Conservation Status, dtype: int64

# %%
clean_species_df = clean_species_df[(clean_species_df['Conservation Status'] != 'Proposed Endangered')]
clean_species_df['Conservation Status'].value_counts()
# Out:
# Least Concern          84785
# Species of Concern      3459
# Endangered               244
# Threatened               136
# In Recovery               69
# Proposed Threatened        6
# Name: Conservation Status, dtype: int64

# %%
clean_species_df = clean_species_df[(clean_species_df['Conservation Status'] != 'Proposed Threatened')]
clean_species_df['Conservation Status'].value_counts()
# Out:
# Least Concern         84785
# Species of Concern     3459
# Endangered              244
# Threatened              136
# In Recovery              69
# Name: Conservation Status, dtype: int64

# %%
clean_species_df.head()
# Out:
#   Species ID             Park Name Category         Order    Family  \
# 0  ACAD-1000  Acadia National Park   Mammal  Artiodactyla  Cervidae
# 1  ACAD-1001  Acadia National Park   Mammal  Artiodactyla  Cervidae
# 2  ACAD-1002  Acadia National Park   Mammal     Carnivora   Canidae
# 3  ACAD-1003  Acadia National Park   Mammal     Carnivora   Canidae
# 5  ACAD-1005  Acadia National Park   Mammal     Carnivora   Felidae
#
#           Scientific Name                                       Common Names  \
# 0             Alces alces                                              Moose
# 1  Odocoileus virginianus  Northern White-Tailed Deer, Virginia Deer, Whi...
# 2           Canis latrans                             Coyote, Eastern Coyote
# 3             Canis lupus        Eastern Timber Wolf, Gray Wolf, Timber Wolf
# 5         Lynx canadensis                                        Canada Lynx
#
#       Occurrence  Nativeness Conservation Status
# 0        Present      Native       Least Concern
# 1        Present      Native       Least Concern
# 2        Present  Not Native  Species of Concern
# 3  Not Confirmed      Native          Endangered
# 5  Not Confirmed      Native       Least Concern

# %%
clean_species_df.isnull().sum()
# Out:
# Species ID                0
# Park Name                 0
# Category                  0
# Order                   471
# Family                  427
# Scientific Name           0
# Common Names              0
# Occurrence                0
# Nativeness             4872
# Conservation Status       0
# dtype: int64

# %%
clean_species_df = clean_species_df.dropna()

# %%
clean_species_df.isnull().sum()
# Out:
# Species ID             0
# Park Name              0
# Category               0
# Order                  0
# Family                 0
# Scientific Name        0
# Common Names           0
# Occurrence             0
# Nativeness             0
# Conservation Status    0
# dtype: int64

# %%
clean_species_df.head()
# Out:
#   Species ID             Park Name Category         Order    Family  \
# 0  ACAD-1000  Acadia National Park   Mammal  Artiodactyla  Cervidae
# 1  ACAD-1001  Acadia National Park   Mammal  Artiodactyla  Cervidae
# 2  ACAD-1002  Acadia National Park   Mammal     Carnivora   Canidae
# 3  ACAD-1003  Acadia National Park   Mammal     Carnivora   Canidae
# 5  ACAD-1005  Acadia National Park   Mammal     Carnivora   Felidae
#
#           Scientific Name                                       Common Names  \
# 0             Alces alces                                              Moose
# 1  Odocoileus virginianus  Northern White-Tailed Deer, Virginia Deer, Whi...
# 2           Canis latrans                             Coyote, Eastern Coyote
# 3             Canis lupus        Eastern Timber Wolf, Gray Wolf, Timber Wolf
# 5         Lynx canadensis                                        Canada Lynx
#
#       Occurrence  Nativeness Conservation Status
# 0        Present      Native       Least Concern
# 1        Present      Native       Least Concern
# 2        Present  Not Native  Species of Concern
# 3  Not Confirmed      Native          Endangered
# 5  Not Confirmed      Native       Least Concern

# %%
clean_species_df = clean_species_df.reset_index()
clean_species_df = clean_species_df.drop(columns = 'index')
clean_species_df.head()
# Out:
#   Species ID             Park Name Category         Order    Family  \
# 0  ACAD-1000  Acadia National Park   Mammal  Artiodactyla  Cervidae
# 1  ACAD-1001  Acadia National Park   Mammal  Artiodactyla  Cervidae
# 2  ACAD-1002  Acadia National Park   Mammal     Carnivora   Canidae
# 3  ACAD-1003  Acadia National Park   Mammal     Carnivora   Canidae
# 4  ACAD-1005  Acadia National Park   Mammal     Carnivora   Felidae
#
#           Scientific Name                                       Common Names  \
# 0             Alces alces                                              Moose
# 1  Odocoileus virginianus  Northern White-Tailed Deer, Virginia Deer, Whi...
# 2           Canis latrans                             Coyote, Eastern Coyote
# 3             Canis lupus        Eastern Timber Wolf, Gray Wolf, Timber Wolf
# 4         Lynx canadensis                                        Canada Lynx
#
#       Occurrence  Nativeness Conservation Status
# 0        Present      Native       Least Concern
# 1        Present      Native       Least Concern
# 2        Present  Not Native  Species of Concern
# 3  Not Confirmed      Native          Endangered
# 4  Not Confirmed      Native       Least Concern

# %%
#add a column for park ids
park_ids = []

for species in clean_species_df['Species ID']:

    code = species.split('-', 1)
    park = code[0]
    park_ids.append(park)

# %%
clean_species_df['Park ID'] = park_ids
clean_species_df.head()
# Out:
#   Species ID             Park Name Category         Order    Family  \
# 0  ACAD-1000  Acadia National Park   Mammal  Artiodactyla  Cervidae
# 1  ACAD-1001  Acadia National Park   Mammal  Artiodactyla  Cervidae
# 2  ACAD-1002  Acadia National Park   Mammal     Carnivora   Canidae
# 3  ACAD-1003  Acadia National Park   Mammal     Carnivora   Canidae
# 4  ACAD-1005  Acadia National Park   Mammal     Carnivora   Felidae
#
#           Scientific Name                                       Common Names  \
# 0             Alces alces                                              Moose
# 1  Odocoileus virginianus  Northern White-Tailed Deer, Virginia Deer, Whi...
# 2           Canis latrans                             Coyote, Eastern Coyote
# 3             Canis lupus        Eastern Timber Wolf, Gray Wolf, Timber Wolf
# 4         Lynx canadensis                                        Canada Lynx
#
#       Occurrence  Nativeness Conservation Status Park ID
# 0        Present      Native       Least Concern    ACAD
# 1        Present      Native       Least Concern    ACAD
# 2        Present  Not Native  Species of Concern    ACAD
# 3  Not Confirmed      Native          Endangered    ACAD
# 4  Not Confirmed      Native       Least Concern    ACAD

# %%
#remove the phrase national park from the park names in the park_df
counter = 0

for name in clean_species_df['Park Name']:
    
    new_name = name.replace(' National Park', '')
    
    clean_species_df['Park Name'][counter] = new_name
    counter += 1

clean_species_df.head()
# Out:
#   Species ID Park Name Category         Order    Family  \
# 0  ACAD-1000    Acadia   Mammal  Artiodactyla  Cervidae
# 1  ACAD-1001    Acadia   Mammal  Artiodactyla  Cervidae
# 2  ACAD-1002    Acadia   Mammal     Carnivora   Canidae
# 3  ACAD-1003    Acadia   Mammal     Carnivora   Canidae
# 4  ACAD-1005    Acadia   Mammal     Carnivora   Felidae
#
#           Scientific Name                                       Common Names  \
# 0             Alces alces                                              Moose
# 1  Odocoileus virginianus  Northern White-Tailed Deer, Virginia Deer, Whi...
# 2           Canis latrans                             Coyote, Eastern Coyote
# 3             Canis lupus        Eastern Timber Wolf, Gray Wolf, Timber Wolf
# 4         Lynx canadensis                                        Canada Lynx
#
#       Occurrence  Nativeness Conservation Status Park ID
# 0        Present      Native       Least Concern    ACAD
# 1        Present      Native       Least Concern    ACAD
# 2        Present  Not Native  Species of Concern    ACAD
# 3  Not Confirmed      Native          Endangered    ACAD
# 4  Not Confirmed      Native       Least Concern    ACAD

# %%
#export to csv file
clean_species_df.to_csv('Resources/clean_species.csv', index = False)

# %%
#clean the dataframe for machine learning
learning_species_df = clean_species_df.drop(columns = ['Species ID', 'Order', 'Family', 'Common Names', 'Occurrence', 'Park ID'])
learning_species_df.head()
# Out:
#   Park Name Category         Scientific Name  Nativeness Conservation Status
# 0    Acadia   Mammal             Alces alces      Native       Least Concern
# 1    Acadia   Mammal  Odocoileus virginianus      Native       Least Concern
# 2    Acadia   Mammal           Canis latrans  Not Native  Species of Concern
# 3    Acadia   Mammal             Canis lupus      Native          Endangered
# 4    Acadia   Mammal         Lynx canadensis      Native       Least Concern

# %%
#removing the species from the scientific name but not the genus
genus_list = []

for species in learning_species_df['Scientific Name']:

    species_split = species.split(' ', 1)
    genus = species_split[0]
    genus_list.append(genus)


genus_list
# Out:
# ['Alces',
#  'Odocoileus',
#  'Canis',
#  'Canis',
#  'Lynx',
#  'Lutra',
#  'Martes',
#  'Mustela',
#  'Mustela',
#  'Mustela',
#  'Mustela',
#  'Odobenus',
#  'Halichoerus',
#  'Phoca',
#  'Procyon',
#  'Ursus',
#  'Eptesicus',
#  'Lasionycteris',
#  'Lasiurus',
#  'Lasiurus',
#  'Myotis',
#  'Myotis',
#  'Lepus',
#  'Castor',
#  'Clethrionomys',
#  'Peromyscus',
#  'Peromyscus',
#  'Synaptomys',
#  'Napaeozapus',
#  'Zapus',
#  'Erethizon',
#  'Rattus',
#  'Glaucomys',
#  'Glaucomys',
#  'Glaucomys',
#  'Marmota',
#  'Sciurus',
#  'Tamias',
#  'Tamiasciurus',
#  'Blarina',
#  'Sorex',
#  'Sorex',
#  'Sorex',
#  'Sorex',
#  'Condylura',
#  'Parascalops',
#  'Accipiter',
#  'Accipiter',
#  'Accipiter',
#  'Aquila',
#  'Buteo',
#  'Buteo',
#  'Buteo',
#  'Buteo',
#  'Circus',
#  'Haliaeetus',
#  'Cathartes',
#  'Pandion',
#  'Aix',
#  'Anas',
#  'Anas',
#  'Anas',
#  'Anas',
#  'Anas',
#  'Anas',
#  'Anas',
#  'Anas',
#  'Aythya',
#  'Aythya',
#  'Aythya',
#  'Aythya',
#  'Branta',
#  'Bucephala',
#  'Bucephala',
#  'Camptorhynchus',
#  'Chen',
#  'Clangula',
#  'Histrionicus',
#  'Lophodytes',
#  'Melanitta',
#  'Melanitta',
#  'Melanitta',
#  'Mergus',
#  'Mergus',
#  'Somateria',
#  'Chaetura',
#  'Archilochus',
#  'Selasphorus',
#  'Caprimulgus',
#  'Caprimulgus',
#  'Chordeiles',
#  'Cepphus',
#  'Uria',
#  'Charadrius',
#  'Charadrius',
#  'Charadrius',
#  'Pluvialis',
#  'Pluvialis',
#  'Haematopus',
#  'Chlidonias',
#  'Larus',
#  'Larus',
#  'Larus',
#  'Larus',
#  'Larus',
#  'Larus',
#  'Larus',
#  'Larus',
#  'Larus',
#  'Larus',
#  'Larus',
#  'Pagophila',
#  'Rissa',
#  'Rynchops',
#  'Sterna',
#  'Sterna',
#  'Sterna',
#  'Sterna',
#  'Sterna',
#  'Sterna',
#  'Xema',
#  'Recurvirostra',
#  'Actitis',
#  'Arenaria',
#  'Bartramia',
#  'Calidris',
#  'Calidris',
#  'Calidris',
#  'Calidris',
#  'Calidris',
#  'Calidris',
#  'Calidris',
#  'Calidris',
#  'Calidris',
#  'Catoptrophorus',
#  'Gallinago',
#  'Limnodromus',
#  'Limnodromus',
#  'Numenius',
#  'Numenius',
#  'Numenius',
#  'Phalaropus',
#  'Phalaropus',
#  'Scolopax',
#  'Tringa',
#  'Tringa',
#  'Tringa',
#  'Catharacta',
#  'Stercorarius',
#  'Stercorarius',
#  'Columba',
#  'Ectopistes',
#  'Zenaida',
#  'Ceryle',
#  'Coccyzus',
#  'Coccyzus',
#  'Falco',
#  'Falco',
#  'Falco',
#  'Falco',
#  'Colinus',
#  'Bonasa',
#  'Falcipennis',
#  'Meleagris',
#  'Phasianus',
#  'Gavia',
#  'Gavia',
#  'Gavia',
#  'Grus',
#  'Fulica',
#  'Gallinula',
#  'Porphyrula',
#  'Porzana',
#  'Rallus',
#  'Rallus',
#  'Eremophila',
#  'Bombycilla',
#  'Bombycilla',
#  'Calcarius',
#  'Plectrophenax',
#  'Cardinalis',
#  'Guiraca',
#  'Passerina',
#  'Passerina',
#  'Passerina',
#  'Pheucticus',
#  'Piranga',
#  'Piranga',
#  'Spiza',
#  'Certhia',
#  'Corvus',
#  'Corvus',
#  'Cyanocitta',
#  'Perisoreus',
#  'Ammodramus',
#  'Ammodramus',
#  'Ammodramus',
#  'Junco',
#  'Melospiza',
#  'Melospiza',
#  'Melospiza',
#  'Passerculus',
#  'Pipilo',
#  'Pipilo',
#  'Pipilo',
#  'Pooecetes',
#  'Spizella',
#  'Spizella',
#  'Spizella',
#  'Zonotrichia',
#  'Zonotrichia',
#  'Carduelis',
#  'Carduelis',
#  'Carduelis',
#  'Carpodacus',
#  'Carpodacus',
#  'Loxia',
#  'Hirundo',
#  'Petrochelidon',
#  'Progne',
#  'Riparia',
#  'Stelgidopteryx',
#  'Tachycineta',
#  'Agelaius',
#  'Dolichonyx',
#  'Euphagus',
#  'Euphagus',
#  'Icterus',
#  'Icterus',
#  'Icterus',
#  'Molothrus',
#  'Quiscalus',
#  'Sturnella',
#  'Xanthocephalus',
#  'Lanius',
#  'Dumetella',
#  'Toxostoma',
#  'Anthus',
#  'Baeolophus',
#  'Poecile',
#  'Poecile',
#  'Dendroica',
#  'Dendroica',
#  'Dendroica',
#  'Dendroica',
#  'Dendroica',
#  'Dendroica',
#  'Dendroica',
#  'Dendroica',
#  'Dendroica',
#  'Dendroica',
#  'Dendroica',
#  'Dendroica',
#  'Dendroica',
#  'Geothlypis',
#  'Helmitheros',
#  'Mniotilta',
#  'Oporornis',
#  'Oporornis',
#  'Oporornis',
#  'Parula',
#  'Protonotaria',
#  'Seiurus',
#  'Seiurus',
#  'Seiurus',
#  'Setophaga',
#  'Vermivora',
#  'Vermivora',
#  'Vermivora',
#  'Vermivora',
#  'Wilsonia',
#  'Wilsonia',
#  'Wilsonia',
#  'Passer',
#  'Polioptila',
#  'Regulus',
#  'Regulus',
#  'Sitta',
#  'Sitta',
#  'Sturnus',
#  'Cistothorus',
#  'Cistothorus',
#  'Thryothorus',
#  'Troglodytes',
#  'Catharus',
#  'Catharus',
#  'Catharus',
#  'Catharus',
#  'Hylocichla',
#  'Ixoreus',
#  'Myadestes',
#  'Sialia',
#  'Turdus',
#  'Contopus',
#  'Contopus',
#  'Empidonax',
#  'Empidonax',
#  'Empidonax',
#  'Empidonax',
#  'Myiarchus',
#  'Myiarchus',
#  'Pyrocephalus',
#  'Sayornis',
#  'Sayornis',
#  'Tyrannus',
#  'Tyrannus',
#  'Tyrannus',
#  'Vireo',
#  'Vireo',
#  'Vireo',
#  'Vireo',
#  'Vireo',
#  'Vireo',
#  'Ardea',
#  'Ardea',
#  'Botaurus',
#  'Bubulcus',
#  'Butorides',
#  'Egretta',
#  'Egretta',
#  'Egretta',
#  'Ixobrychus',
#  'Nyctanassa',
#  'Nycticorax',
#  'Nycticorax',
#  'Pelecanus',
#  'Plegadis',
#  'Colaptes',
#  'Dryocopus',
#  'Melanerpes',
#  'Melanerpes',
#  'Picoides',
#  'Picoides',
#  'Picoides',
#  'Sphyrapicus',
#  'Podiceps',
#  'Podiceps',
#  'Podiceps',
#  'Podilymbus',
#  'Diomedea',
#  'Oceanites',
#  'Oceanodroma',
#  'Calonectris',
#  'Fulmarus',
#  'Puffinus',
#  'Puffinus',
#  'Puffinus',
#  'Aegolius',
#  'Aegolius',
#  'Asio',
#  'Bubo',
#  'Nyctea',
#  'Otus',
#  'Strix',
#  'Strix',
#  'Surnia',
#  'Fregata',
#  'Phalacrocorax',
#  'Phalacrocorax',
#  'Morus',
#  'Diadophis',
#  'Lampropeltis',
#  'Liochlorophis',
#  'Storeria',
#  'Thamnophis',
#  'Chelydra',
#  'Chrysemys',
#  'Clemmys',
#  'Terrapene',
#  'Bufo',
#  'Pseudacris',
#  'Rana',
#  'Rana',
#  'Rana',
#  'Rana',
#  'Ambystoma',
#  'Ambystoma',
#  'Desmognathus',
#  'Eurycea',
#  'Hemidactylium',
#  'Notophthalmus',
#  'Anguilla',
#  'Menidia',
#  'Alosa',
#  'Catostomus',
#  'Luxilus',
#  'Notemigonus',
#  'Phoxinus',
#  'Semotilus',
#  'Semotilus',
#  'Fundulus',
#  'Esox',
#  'Apeltes',
#  'Gasterosteus',
#  'Pungitius',
#  'Osmerus',
#  'Lepomis',
#  'Micropterus',
#  'Micropterus',
#  'Morone',
#  'Perca',
#  'Salmo',
#  'Salmo',
#  'Salvelinus',
#  'Salvelinus',
#  'Ameiurus',
#  'Acorus',
#  'Alisma',
#  'Sagittaria',
#  'Sagittaria',
#  'Arisaema',
#  'Calla',
#  'Lemna',
#  'Symplocarpus',
#  'Najas',
#  'Najas',
#  'Vallisneria',
#  'Triglochin',
#  'Potamogeton',
#  'Potamogeton',
#  'Potamogeton',
#  'Potamogeton',
#  'Potamogeton',
#  'Potamogeton',
#  'Potamogeton',
#  'Potamogeton',
#  'Potamogeton',
#  'Potamogeton',
#  'Potamogeton',
#  'Stuckenia',
#  'Zannichellia',
#  'Ruppia',
#  'Scheuchzeria',
#  'Zostera',
#  'Aegopodium',
#  'Angelica',
#  'Angelica',
#  'Carum',
#  'Cicuta',
#  'Cicuta',
#  'Daucus',
#  'Heracleum',
#  'Ligusticum',
#  'Osmorhiza',
#  'Pastinaca',
#  'Pimpinella',
#  'Sium',
#  'Zizia',
#  'Aralia',
#  'Aralia',
#  'Aralia',
#  'Aralia',
#  'Hydrocotyle',
#  'Ilex',
#  'Ilex',
#  'Nemopanthus',
#  'Allium',
#  'Asparagus',
#  'Maianthemum',
#  'Maianthemum',
#  'Maianthemum',
#  'Maianthemum',
#  'Polygonatum',
#  'Iris',
#  'Iris',
#  'Iris',
#  'Sisyrinchium',
#  'Sisyrinchium',
#  'Sisyrinchium',
#  'Sisyrinchium',
#  'Arethusa',
#  'Calopogon',
#  'Coeloglossum',
#  'Corallorrhiza',
#  'Cypripedium',
#  'Epipactis',
#  'Goodyera',
#  'Goodyera',
#  'Goodyera',
#  'Listera',
#  'Listera',
#  'Listera',
#  'Malaxis',
#  'Platanthera',
#  'Platanthera',
#  'Platanthera',
#  'Platanthera',
#  'Platanthera',
#  'Platanthera',
#  'Platanthera',
#  'Platanthera',
#  'Pogonia',
#  'Spiranthes',
#  'Spiranthes',
#  'Spiranthes',
#  'Hemerocallis',
#  'Achillea',
#  'Achillea',
#  'Ambrosia',
#  'Ambrosia',
#  'Ambrosia',
#  'Anaphalis',
#  'Antennaria',
#  'Antennaria',
#  'Antennaria',
#  'Antennaria',
#  'Antennaria',
#  'Antennaria',
#  'Antennaria',
#  'Anthemis',
#  'Arctium',
#  'Arctium',
#  'Arctium',
#  'Arnoseris',
#  'Artemisia',
#  'Artemisia',
#  'Aster',
#  'Aster',
#  'Bidens',
#  'Bidens',
#  'Bidens',
#  'Bidens',
#  'Centaurea',
#  'Centaurea',
#  'Chrysanthemum',
#  'Cichorium',
#  'Cirsium',
#  'Cirsium',
#  'Cirsium',
#  'Cirsium',
#  'Conyza',
#  'Doellingeria',
#  'Echinops',
#  'Erechtites',
#  'Erigeron',
#  'Erigeron',
#  'Eupatorium',
#  'Eupatorium',
#  'Euthamia',
#  'Euthamia',
#  'Galinsoga',
#  'Gnaphalium',
#  'Helianthus',
#  'Helianthus',
#  'Helianthus',
#  'Heliopsis',
#  'Hieracium',
#  'Hieracium',
#  'Hieracium',
#  'Hieracium',
#  'Hieracium',
#  'Hieracium',
#  'Hieracium',
#  'Hieracium',
#  'Hieracium',
#  'Hieracium',
#  'Hieracium',
#  'Lactuca',
#  'Lactuca',
#  'Lactuca',
#  'Lactuca',
#  'Lactuca',
#  'Lapsana',
#  'Leontodon',
#  'Leontodon',
#  'Leucanthemum',
#  'Matricaria',
#  'Matricaria',
#  'Matricaria',
#  'Matricaria',
#  'Mycelis',
#  'Oclemena',
#  'Oclemena',
#  'Oclemena',
#  'Petasites',
#  'Prenanthes',
#  'Prenanthes',
#  'Prenanthes',
#  'Pseudognaphalium',
#  'Pseudognaphalium',
#  'Rudbeckia',
#  'Rudbeckia',
#  'Senecio',
#  'Senecio',
#  'Senecio',
#  'Senecio',
#  'Senecio',
#  'Solidago',
#  'Solidago',
#  'Solidago',
#  'Solidago',
#  'Solidago',
#  'Solidago',
#  'Solidago',
#  'Solidago',
#  'Solidago',
#  'Solidago',
#  'Solidago',
#  'Solidago',
#  'Solidago',
#  'Sonchus',
#  'Sonchus',
#  'Sonchus',
#  'Symphyotrichum',
#  'Symphyotrichum',
#  'Symphyotrichum',
#  'Symphyotrichum',
#  'Symphyotrichum',
#  'Symphyotrichum',
#  'Symphyotrichum',
#  'Symphyotrichum',
#  'Symphyotrichum',
#  'Symphyotrichum',
#  'Symphyotrichum',
#  'Symphyotrichum',
#  'Tanacetum',
#  'Taraxacum',
#  'Taraxacum',
#  'Tragopogon',
#  'Tragopogon',
#  'Tussilago',
#  'Campanula',
#  'Campanula',
#  'Campanula',
#  'Lobelia',
#  'Lobelia',
#  'Lobelia',
#  'Lobelia',
#  'Triodanis',
#  'Menyanthes',
#  'Nymphoides',
#  'Anchusa',
#  'Borago',
#  'Lappula',
#  'Mertensia',
#  'Myosotis',
#  'Myosotis',
#  'Myosotis',
#  'Myosotis',
#  'Myosotis',
#  'Symphytum',
#  'Alliaria',
#  'Alyssum',
#  'Arabis',
#  'Arabis',
#  'Armoracia',
#  'Barbarea',
#  'Berteroa',
#  'Brassica',
#  'Brassica',
#  'Brassica',
#  'Cakile',
#  'Camelina',
#  'Camelina',
#  'Capsella',
#  'Cardamine',
#  'Cardamine',
#  'Cardamine',
#  'Cardamine',
#  'Conringia',
#  'Draba',
#  'Erysimum',
#  'Hesperis',
#  'Iberis',
#  'Lepidium',
#  'Lepidium',
#  'Lepidium',
#  'Raphanus',
#  'Raphanus',
#  'Rorippa',
#  'Rorippa',
#  'Sinapis',
#  'Sisymbrium',
#  'Sisymbrium',
#  'Subularia',
#  'Thlaspi',
#  'Reseda',
#  'Amaranthus',
#  'Amaranthus',
#  'Amaranthus',
#  'Atriplex',
#  'Atriplex',
#  'Atriplex',
#  'Atriplex',
#  'Atriplex',
#  'Chenopodium',
#  'Chenopodium',
#  'Chenopodium',
#  'Chenopodium',
#  'Salicornia',
#  'Salicornia',
#  'Salsola',
#  'Suaeda',
#  'Suaeda',
#  'Suaeda',
#  'Suaeda',
#  'Cerastium',
#  'Cerastium',
#  'Cerastium',
#  'Dianthus',
#  'Dianthus',
#  'Dianthus',
#  'Honckenya',
#  'Minuartia',
#  'Minuartia',
#  'Moehringia',
#  'Sagina',
#  'Sagina',
#  'Sagina',
#  'Saponaria',
#  'Silene',
#  'Silene',
#  'Silene',
#  'Silene',
#  'Silene',
#  'Spergula',
#  'Spergularia',
#  'Spergularia',
#  'Spergularia',
#  'Stellaria',
#  'Stellaria',
#  'Stellaria',
#  'Stellaria',
#  'Stellaria',
#  'Stellaria',
#  'Stellaria',
#  'Vaccaria',
#  'Drosera',
#  'Drosera',
#  'Mollugo',
#  'Montia',
#  'Limonium',
#  'Fagopyrum',
#  'Fallopia',
#  'Fallopia',
#  'Fallopia',
#  'Fallopia',
#  'Persicaria',
#  'Persicaria',
#  'Persicaria',
#  'Persicaria',
#  'Persicaria',
#  'Persicaria',
#  'Persicaria',
#  'Persicaria',
#  'Polygonella',
#  'Polygonum',
#  'Polygonum',
#  'Polygonum',
#  'Polygonum',
#  'Polygonum',
#  'Polygonum',
#  'Rumex',
#  'Rumex',
#  'Rumex',
#  'Rumex',
#  'Rumex',
#  'Rumex',
#  'Rumex',
#  'Rumex',
#  'Rumex',
#  'Rumex',
#  'Portulaca',
#  'Celastrus',
#  'Ceratophyllum',
#  'Pontederia',
#  'Cornus',
#  'Cornus',
#  'Cornus',
#  'Cornus',
#  'Echinocystis',
#  'Sambucus',
#  'Sambucus',
#  'Viburnum',
#  'Viburnum',
#  'Viburnum',
#  'Viburnum',
#  'Viburnum',
#  'Viburnum',
#  'Lonicera',
#  'Lonicera',
#  'Lonicera',
#  'Lonicera',
#  'Lonicera',
#  'Lonicera',
#  'Lonicera',
#  'Lonicera',
#  'Symphoricarpos',
#  'Diervilla',
#  'Linnaea',
#  'Valeriana',
#  'Equisetum',
#  'Equisetum',
#  'Equisetum',
#  'Actinidia',
#  'Impatiens',
#  'Impatiens',
#  'Andromeda',
#  'Arctostaphylos',
#  'Calluna',
#  'Chamaedaphne',
#  'Chimaphila',
#  'Corema',
#  'Empetrum',
#  'Epigaea',
#  'Gaultheria',
#  'Gaultheria',
#  'Gaylussacia',
#  'Gaylussacia',
#  'Kalmia',
#  'Kalmia',
#  'Moneses',
#  'Monotropa',
#  'Monotropa',
#  'Orthilia',
#  'Pyrola',
#  'Pyrola',
#  'Pyrola',
#  'Rhododendron',
#  'Rhododendron',
#  'Vaccinium',
#  'Vaccinium',
#  'Vaccinium',
#  'Vaccinium',
#  'Vaccinium',
#  'Vaccinium',
#  'Vaccinium',
#  'Vaccinium',
#  'Vaccinium',
#  'Anagallis',
#  'Glaux',
#  'Glaux',
#  'Lysimachia',
#  'Lysimachia',
#  'Lysimachia',
#  'Lysimachia',
#  'Lysimachia',
#  'Lysimachia',
#  'Trientalis',
#  'Sarracenia',
#  'Amphicarpaea',
#  'Apios',
#  'Coronilla',
#  'Genista',
#  'Lathyrus',
#  'Lathyrus',
#  'Lathyrus',
#  'Lathyrus',
#  'Lotus',
#  'Lupinus',
#  'Medicago',
#  'Medicago',
#  'Melilotus',
#  'Robinia',
#  'Robinia',
#  'Robinia',
#  'Thermopsis',
#  'Trifolium',
#  'Trifolium',
#  'Trifolium',
#  'Trifolium',
#  'Trifolium',
#  'Trifolium',
#  'Trifolium',
#  'Vicia',
#  'Vicia',
#  'Vicia',
#  'Vicia',
#  'Vicia',
#  'Vicia',
#  'Polygala',
#  'Polygala',
#  'Polygala',
#  'Alnus',
#  'Alnus',
#  'Betula',
#  'Betula',
#  'Betula',
#  'Betula',
#  'Betula',
#  'Corylus',
#  'Ostrya',
#  'Fagus',
#  'Quercus',
#  'Quercus',
#  'Comptonia',
#  'Myrica',
#  'Myrica',
#  'Apocynum',
#  'Apocynum',
#  'Asclepias',
#  'Asclepias',
#  'Bartonia',
#  'Bartonia',
#  'Lomatogonium',
#  'Cephalanthus',
#  'Galium',
#  'Galium',
#  'Galium',
#  'Galium',
#  'Galium',
#  'Galium',
#  'Galium',
#  'Houstonia',
#  'Mitchella',
#  'Geranium',
#  'Geranium',
#  'Geranium',
#  'Isoetes',
#  'Isoetes',
#  'Isoetes',
#  'Isoetes',
#  'Isoetes',
#  'Isoetes',
#  'Galeopsis',
#  'Galeopsis',
#  'Glechoma',
#  'Hedeoma',
#  'Lycopus',
#  'Lycopus',
#  'Mentha',
#  'Mentha',
#  'Mentha',
#  'Mentha',
#  'Prunella',
#  'Prunella',
#  'Satureja',
#  'Scutellaria',
#  'Scutellaria',
#  'Stachys',
#  'Stachys',
#  'Teucrium',
#  'Teucrium',
#  'Thymus',
#  'Utricularia',
#  'Utricularia',
#  'Utricularia',
#  'Utricularia',
#  'Utricularia',
#  'Utricularia',
#  'Utricularia',
#  'Utricularia',
#  'Lindernia',
#  'Forsythia',
#  'Fraxinus',
#  'Fraxinus',
#  'Fraxinus',
#  'Ligustrum',
#  'Ligustrum',
#  'Syringa',
#  'Syringa',
#  'Epifagus',
#  'Euphrasia',
#  'Euphrasia',
#  'Euphrasia',
#  'Melampyrum',
#  'Odontites',
#  'Orobanche',
#  'Pedicularis',
#  'Rhinanthus',
#  'Callitriche',
#  'Callitriche',
#  'Chelone',
#  'Chelone',
#  'Digitalis',
#  'Linaria',
#  'Linaria',
#  'Nuttallanthus',
#  'Penstemon',
#  'Plantago',
#  'Plantago',
#  'Plantago',
#  'Plantago',
#  'Plantago',
#  'Veronica',
#  'Veronica',
#  'Veronica',
#  'Veronica',
#  'Veronica',
#  'Veronica',
#  'Veronica',
#  'Veronica',
#  'Veronicastrum',
#  'Scrophularia',
#  'Verbascum',
#  'Verbascum',
#  'Verbena',
#  'Uvularia',
#  'Clintonia',
#  'Erythronium',
#  'Lilium',
#  'Lilium',
#  'Lilium',
#  'Medeola',
#  'Streptopus',
#  'Streptopus',
#  'Trillium',
#  'Trillium',
#  'Veratrum',
#  'Diphasiastrum',
#  ...]

# %%
learning_species_df['Genus'] = genus_list
learning_species_df.head()
# Out:
#   Park Name Category         Scientific Name  Nativeness Conservation Status  \
# 0    Acadia   Mammal             Alces alces      Native       Least Concern
# 1    Acadia   Mammal  Odocoileus virginianus      Native       Least Concern
# 2    Acadia   Mammal           Canis latrans  Not Native  Species of Concern
# 3    Acadia   Mammal             Canis lupus      Native          Endangered
# 4    Acadia   Mammal         Lynx canadensis      Native       Least Concern
#
#         Genus
# 0       Alces
# 1  Odocoileus
# 2       Canis
# 3       Canis
# 4        Lynx

# %%
learning_species_df = learning_species_df[['Genus', 'Category', 'Park Name', 'Conservation Status', 'Nativeness', 'Scientific Name']]
learning_species_df.head()
# Out:
#         Genus Category Park Name Conservation Status  Nativeness  \
# 0       Alces   Mammal    Acadia       Least Concern      Native
# 1  Odocoileus   Mammal    Acadia       Least Concern      Native
# 2       Canis   Mammal    Acadia  Species of Concern  Not Native
# 3       Canis   Mammal    Acadia          Endangered      Native
# 4        Lynx   Mammal    Acadia       Least Concern      Native
#
#           Scientific Name
# 0             Alces alces
# 1  Odocoileus virginianus
# 2           Canis latrans
# 3             Canis lupus
# 4         Lynx canadensis

# %%
learning_species_df = learning_species_df.drop(columns = 'Scientific Name')
learning_species_df.head()
# Out:
#         Genus Category Park Name Conservation Status  Nativeness
# 0       Alces   Mammal    Acadia       Least Concern      Native
# 1  Odocoileus   Mammal    Acadia       Least Concern      Native
# 2       Canis   Mammal    Acadia  Species of Concern  Not Native
# 3       Canis   Mammal    Acadia          Endangered      Native
# 4        Lynx   Mammal    Acadia       Least Concern      Native

# %%
learning_species_df.to_csv('Resources/learning_species.csv', index = False)
